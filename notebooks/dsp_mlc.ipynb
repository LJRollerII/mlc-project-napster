# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
mlc = pd.read_csv('C:/NSS/Projects/mlc-project-napster/data/Matching Sample for NSS (100k Lines).xlsx - MLC Data Sample.csv')

# %%
mlc.columns = ['isrc', 'country_code', 'registrant_code', 'year', 'usage_period', 'dsp', 'streams', 'recording_artist', 'recording_label', 'recording_title', 'release_title', 'duration', 'songwriters_listed']
mlc.head()
# Out:
#            isrc country_code registrant_code      year usage_period  \
# 0  USUG12101043           US             UG1 21.000000          NaN
# 1  USRC12100543           US             RC1 21.000000          NaN
# 2  USSM12102263           US             SM1 21.000000          NaN
# 3  USLD91731547           US             LD9 17.000000     2/1/2021
# 4  USAT22007048           US             AT2 20.000000          NaN
#
#           dsp     streams        recording_artist recording_label  \
# 0   AudioMack     10,175                   Future             NaN
# 1  SoundCloud      8,597                 LUCKY3RD        LUCKY3RD
# 2  SoundCloud    261,280                 LUCKY3RD        LUCKY3RD
# 3      Trebel          5   Bachata & Merengue Mix         Orchard
# 4   AudioMack     62,105                   Foolio             NaN
#
#                              recording_title            release_title  \
# 0   FUTURE FT DEJ LOAF HEY THERE PROD BY DDS                #unknown#
# 1                     Keep It Cool  LUCKY3RD   Keep It Cool  LUCKY3RD
# 2                     Life Goes On  LUCKY3RD   Life Goes On  LUCKY3RD
# 3     No dudes de mi- Merengue & Bachata Mix            Mega Mix 2010
# 4                       WHEN I SEE YOU REMIX                #unknown#
#
#    duration  songwriters_listed
# 0       181                   0
# 1       133                   0
# 2       171                   0
# 3      1250                   0
# 4       187                   0

# %%
mlc['year'] = mlc['year'].astype('Int64')

# %%
mlc.head()
# Out:
#            isrc country_code registrant_code  year usage_period         dsp  \
# 0  USUG12101043           US             UG1    21          NaN   AudioMack
# 1  USRC12100543           US             RC1    21          NaN  SoundCloud
# 2  USSM12102263           US             SM1    21          NaN  SoundCloud
# 3  USLD91731547           US             LD9    17     2/1/2021      Trebel
# 4  USAT22007048           US             AT2    20          NaN   AudioMack
#
#       streams        recording_artist recording_label  \
# 0     10,175                   Future             NaN
# 1      8,597                 LUCKY3RD        LUCKY3RD
# 2    261,280                 LUCKY3RD        LUCKY3RD
# 3          5   Bachata & Merengue Mix         Orchard
# 4     62,105                   Foolio             NaN
#
#                              recording_title            release_title  \
# 0   FUTURE FT DEJ LOAF HEY THERE PROD BY DDS                #unknown#
# 1                     Keep It Cool  LUCKY3RD   Keep It Cool  LUCKY3RD
# 2                     Life Goes On  LUCKY3RD   Life Goes On  LUCKY3RD
# 3     No dudes de mi- Merengue & Bachata Mix            Mega Mix 2010
# 4                       WHEN I SEE YOU REMIX                #unknown#
#
#    duration  songwriters_listed
# 0       181                   0
# 1       133                   0
# 2       171                   0
# 3      1250                   0
# 4       187                   0

# %%
mlc['streams']=mlc['streams'].str.replace(',','')

# %%
mlc['streams']=mlc['streams'].astype(int)

# %%
mlc.sort_values(
     by="streams",
     ascending=False,
    ).reset_index().head(10)
# Out:
#    index          isrc country_code registrant_code  year usage_period  \
# 0  46643  USAT21901833           US             AT2    19     4/1/2021
# 1  89141  TCAEW2013140           TC             AEW    20     4/1/2021
# 2  24773  USUG12003339           US             UG1    20     1/1/2021
# 3  48604  QM4DW1706229           QM             4DW    17     3/1/2021
# 4  27720  USUM72104713           US             UM7    21          NaN
# 5  52503  QZNJV2050806           QZ             NJV    20     5/1/2021
# 6  55656  TCADQ1824662           TC             ADQ    18     5/1/2021
# 7  65920  QZHN82036983           QZ             HN8    20     1/1/2021
# 8  89142  UKP3G2001318           UK             P3G    20     4/1/2021
# 9  66711  USKBB2100008           US             KBB    21     4/1/2021
#
#           dsp   streams            recording_artist  \
# 0     Spotify  21456166                Doja Cat,SZA
# 1       Apple  17259260                    Rod Wave
# 2     Spotify  17109896              Olivia Rodrigo
# 3       Apple  16216932                       Drake
# 4       Apple  15747471                   DJ Khaled
# 5     Spotify  14847867    J. Cole,21 Savage,Morray
# 6     Spotify  14265940  Trippie Redd,Playboi Carti
# 7     Pandora  12413368            2Pac|The Outlawz
# 8       Apple   9131964                    Rod Wave
# 9  SoundCloud   9072859                      Polo G
#
#                                      recording_label  \
# 0                       Kemosabe Records/RCA Records
# 1                                      Alamo Records
# 2                                  Olivia Rodrigo PS
# 3                                                OVO
# 4                                   Epic/We The Best
# 5  Dreamville, Inc., Under exclusive license to R...
# 6                 1400 Entertainment  / 10K Projects
# 7                                         eOne Music
# 8                                      Alamo Records
# 9                                           Columbia
#
#                                   recording_title  \
# 0                        Kiss Me More (feat. SZA)
# 1                                       Tombstone
# 2                                 drivers license
# 3        Lemon Pepper Freestyle (feat. Rick Ross)
# 4  EVERY CHANCE I GET (feat. Lil Baby & Lil Durk)
# 5         m y . l i f e (with 21 Savage & Morray)
# 6             Miss The Rage (feat. Playboi Carti)
# 7          Picture Me Rollin' (feat. The Outlawz)
# 8                                       Tombstone
# 9                                Polo G - RAPSTAR
#
#                          release_title  duration  songwriters_listed
# 0             Kiss Me More (feat. SZA)       209                   1
# 1                              SoulFly       160                   1
# 2                      drivers license       243                   1
# 3                        Scary Hours 2       383                   1
# 4                        KHALED KHALED       237                   1
# 5                       The Off-Season       219                   1
# 6  Miss The Rage (feat. Playboi Carti)       237                   1
# 7                  Dust storm in Vegas       310                   0
# 8                              SoulFly       160                   1
# 9                     Polo G - RAPSTAR       165                   0

# %% [markdown]
# mlc['year'] = mlc['year'].fillna(-999)

# %% [markdown]
# def foo(row):   # row is a Series
#     if row.year >= 0 and row.year <= 22:
#         return row.year + 2000
#     else:
#         return row.year + 1900
#
# mlc["year"] = mlc.apply(foo, axis=1)
# mlc.head()

# %%
mlc['year'].value_counts()
# Out:
# 20    31143
# 21    13510
# 19    11577
# 18     8556
# 17     6025
#       ...
# 44        2
# 50        1
# 48        1
# 49        1
# 40        1
# Name: year, Length: 95, dtype: Int64

# %%
doja = mlc["recording_title"].isin(["Kiss Me More (feat. SZA)"])

# %%
mlc[doja].sort_values(
     by="streams",
     ascending=False,
    ).reset_index().head(10)
# Out:
#    index          isrc country_code registrant_code  year usage_period  \
# 0  46643  USAT21901833           US             AT2    19     4/1/2021
# 1  46644  USDXS1800064           US             DXS    18     4/1/2021
# 2  46645  TCAEG1966838           TC             AEG    19     4/1/2021
# 3  46647           NaN          NaN             NaN  <NA>     5/1/2021
# 4  46646           NaN          NaN             NaN  <NA>     5/1/2021
#
#        dsp   streams recording_artist               recording_label  \
# 0  Spotify  21456166     Doja Cat,SZA  Kemosabe Records/RCA Records
# 1    Apple   8363904         Doja Cat  Kemosabe Records/RCA Records
# 2    Apple    923571         Doja Cat  Kemosabe Records/RCA Records
# 3    Apple    306812         Doja Cat  Kemosabe Records/RCA Records
# 4    Apple    272088         Doja Cat  Kemosabe Records/RCA Records
#
#             recording_title                      release_title  duration  \
# 0  Kiss Me More (feat. SZA)           Kiss Me More (feat. SZA)       209
# 1  Kiss Me More (feat. SZA)  Kiss Me More (feat. SZA) - Single       209
# 2  Kiss Me More (feat. SZA)  Kiss Me More (feat. SZA) - Single       209
# 3  Kiss Me More (feat. SZA)  Kiss Me More (feat. SZA) - Single       209
# 4  Kiss Me More (feat. SZA)  Kiss Me More (feat. SZA) - Single       209
#
#    songwriters_listed
# 0                   1
# 1                   1
# 2                   1
# 3                   1
# 4                   1

# %%
doja_kmm = mlc[doja].groupby(['dsp'])['streams'].sum().sort_values(ascending=False)
doja_kmm = pd.DataFrame(doja_kmm)

# %%
kmm_list = [{'Spotify', 21456166},{'Apple', 9866375}]

# %%
doja_kmm = pd.DataFrame(kmm_list)

# %%
doja_kmm.head()
# Out:
#          0         1
# 0  Spotify  21456166
# 1  9866375     Apple

# %%
plt.pie(doja_kmm[1], labels=doja_kmm[0])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8204/3277511912.py in <module>
# ----> 1 plt.pie(doja_kmm[1], labels=doja_kmm[0])
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in pie(x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels, normalize, data)
#    3004         textprops=None, center=(0, 0), frame=False,
#    3005         rotatelabels=False, *, normalize=None, data=None):
# -> 3006     return gca().pie(
#    3007         x, explode=explode, labels=labels, colors=colors,
#    3008         autopct=autopct, pctdistance=pctdistance, shadow=shadow,
#
# ~\anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1359     def inner(ax, *args, data=None, **kwargs):
#    1360         if data is None:
# -> 1361             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1362
#    1363         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_axes.py in pie(self, x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels, normalize)
#    3028         # The use of float32 is "historical", but can't be changed without
#    3029         # regenerating the test baselines.
# -> 3030         x = np.asarray(x, np.float32)
#    3031         if x.ndim > 1:
#    3032             raise ValueError("x must be 1D")
#
# ~\anaconda3\lib\site-packages\numpy\core\_asarray.py in asarray(a, dtype, order, like)
#     100         return _asarray_with_like(a, dtype=dtype, order=order, like=like)
#     101
# --> 102     return array(a, dtype, copy=False, order=order)
#     103
#     104
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in __array__(self, dtype)
#     855               dtype='datetime64[ns]')
#     856         """
# --> 857         return np.asarray(self._values, dtype)
#     858
#     859     # ----------------------------------------------------------------------
#
# ~\anaconda3\lib\site-packages\numpy\core\_asarray.py in asarray(a, dtype, order, like)
#     100         return _asarray_with_like(a, dtype=dtype, order=order, like=like)
#     101
# --> 102     return array(a, dtype, copy=False, order=order)
#     103
#     104
#
# ValueError: could not convert string to float: 'Apple'

# %% [markdown]
# ### Doja Cat "Kiss Me More (feat. SZA)" total streams per dsp

# %%
doja_kmm.head()
# Out:
#          0         1
# 0  Spotify  21456166
# 1  9866375     Apple

# %%
mlc.groupby(['dsp'])['songwriters_listed'].count().sort_values(ascending=False)
# Out:
# dsp
# Spotify               32268
# Apple                 22200
# Amazon                14438
# Pandora               13777
# Tidal                  3521
# YouTube                2752
# SoundCloud             2122
# GTL                    1090
# Melodyv                 829
# Trebel                  817
# iHeart Radio            707
# AudioMack               550
# NugsNet                 316
# LiveXLive               200
# Qoboz                   104
# Midwest Tape            102
# Deezer                   51
# Anghami                  46
# Sonos                    23
# Recisio                  22
# Smithsonian              21
# Ultimate Guitar          19
# PowerMusic                8
# Wolfgangs                 4
# MixCloud                  4
# Fan Label                 4
# Pacemaker                 3
# Classical Archives        2
# MonkingMe                 1
# Name: songwriters_listed, dtype: int64

# %%
stream_sum_dsp = mlc.groupby(['dsp'])['streams'].sum().sort_values(ascending=False)

# %% [markdown]
# ## Cell below suppresses scientific notation

# %%
pd.options.display.float_format = '{:f}'.format

# %% [markdown]
# ## Total streams

# %%
top_5_dsp_stream = stream_sum_dsp.head(5)
top_5_dsp_stream.head()
# Out:
# dsp
# Spotify      2552563722.000000
# Apple        1606453701.000000
# Pandora       874236566.000000
# SoundCloud    166813813.000000
# YouTube       158031119.000000
# Name: streams, dtype: float64

# %% [markdown]
# ## Cell below displays scientific notation

# %%
pd.reset_option('^display.', silent=True)

# %%
stream_sum_dsp = mlc.groupby(['dsp'])['streams'].sum().sort_values(ascending=False)

# %%
x = mlc.groupby(['dsp', 'recording_label']).agg({'streams': ['sum']})

# %%
x.columns = ['streams']

# %%
x.sort_values(by='streams',ascending=False).head(50)
# Out:
#                                                                 streams
# dsp        recording_label
# Spotify    Columbia                                            78577968
# Apple      Atlantic Records                                    77914444
# Spotify    Lofi Records                                        69042536
# Apple      Alamo (Geffen Records)                              65041355
# Spotify    Atlantic Records                                    53791329
#            Taylor Swift                                        49625463
# Apple      Alamo Records                                       49017087
#            300 Entertainment                                   46923955
# Spotify    300 Entertainment                                   39668864
#            Republic Records                                    38324304
#            RBMG/Def Jam                                        35669535
# Apple      Platoon                                             31167972
# Spotify    Dreamville, Inc., Under exclusive license to Ro...  31058553
# Apple      CMG/N-Less/Interscope Records                       30751808
#            Epic/We The Best                                    30318317
# Spotify    Filtr                                               29104069
# Apple      Quality Control Music/Motown Records                28260893
#            Jay Rebel Music                                     26575177
# Spotify    Warner Records                                      25537380
# Apple      OVO                                                 25455703
# Pandora    Atlantic Records                                    24138019
# Apple      Columbia                                            24017916
# Spotify    ChilledCow Records                                  23609957
# Pandora    eOne Music                                          23336260
# Apple      Taylor Swift                                        22639649
# Spotify    Kemosabe Records/RCA Records                        22240694
#            Rebel Music PS                                      21902370
#            Kawai Sprite                                        21628327
#            Alamo (Geffen Records)                              21415815
#            MT Recordings                                       21269755
# Apple      RBMG/Def Jam                                        20788908
#            Republic Records                                    20520660
#            Dreamville, Inc., Under exclusive license to Ro...  20515113
#            Only The Family / EMPIRE                            20081988
# Spotify    1400 Entertainment  / 10K Projects                  19959264
# Apple      Warner Records                                      19230989
#            Imaginary Landscapes                                18615689
# Spotify    Olivia Rodrigo PS                                   18034034
#            Island Records                                      17404031
#            Alamo Records                                       16989330
#            New CMG Records P&D                                 16694330
# Apple      Paper Route EMPIRE                                  16112972
#            Guwop Enterprises/Atlantic                          15590237
# SoundCloud Columbia                                            14691114
# Spotify    CORPSE                                              14160075
#            Big Loud / Republic                                 14073735
# Apple      Rancho Humilde                                      13997902
# Spotify    RCA Records Label                                   13556516
# Apple      RCA Records Label                                   13518161
# Spotify    Rostrum Records                                     13376355

# %%
mlc.groupby(['dsp'])['recording_artist'].nunique().sort_values(ascending=False)
# Out:
# dsp
# Spotify               10088
# Pandora                4067
# Apple                  3979
# Amazon                 3112
# Tidal                  1527
# YouTube                1334
# SoundCloud              656
# iHeart Radio            420
# Trebel                  386
# Melodyv                 356
# AudioMack               217
# GTL                     212
# LiveXLive               171
# Deezer                   43
# Qoboz                    37
# Midwest Tape             34
# Recisio                  22
# Anghami                  20
# Smithsonian              20
# NugsNet                  20
# Sonos                    19
# Ultimate Guitar           9
# PowerMusic                8
# MixCloud                  4
# Fan Label                 3
# Wolfgangs                 3
# Pacemaker                 3
# Classical Archives        2
# MonkingMe                 1
# Name: recording_artist, dtype: int64

# %%
mlc.isna().sum()
# Out:
# isrc                  1760
# country_code          1697
# registrant_code       1697
# year                  1761
# usage_period          8102
# dsp                   3999
# streams                  0
# recording_artist         0
# recording_label       1008
# recording_title          0
# release_title           69
# duration                 0
# songwriters_listed       0
# dtype: int64

# %%
usage_streams = mlc.groupby(['usage_period'])['streams'].sum()

# %%
usage_streams.head()
# Out:
# usage_period
# 1/1/2021    1542456426
# 2/1/2021     463411633
# 3/1/2021    1898478487
# 4/1/2021     654260200
# 5/1/2021     753074907
# Name: streams, dtype: int32

# %%
plt.plot(usage_streams)

# %%
usage_period_platform = mlc.groupby(['dsp', 'usage_period']).agg({'streams': ['sum']})

# %%
usage_period_platform.columns = ['streams']

# %%
usage_period_platform.sort_values(by='streams',ascending=False).head(50)
# Out:
#                               streams
# dsp          usage_period
# Spotify      3/1/2021      1070556892
# Pandora      1/1/2021       640744206
# Apple        3/1/2021       596790646
# Spotify      5/1/2021       557532861
#              1/1/2021       497157870
# Apple        1/1/2021       386489626
# Spotify      4/1/2021       233054084
#              2/1/2021       194262015
# Apple        4/1/2021       191327008
#              5/1/2021       152393670
# Pandora      3/1/2021       117910699
# Apple        2/1/2021       103344401
# SoundCloud   4/1/2021        68215817
# Pandora      4/1/2021        61458665
# Amazon       3/1/2021        54551981
#              4/1/2021        45677976
# YouTube      2/1/2021        43092176
# SoundCloud   2/1/2021        41528178
# YouTube      4/1/2021        39801971
# Amazon       2/1/2021        31398796
# Pandora      5/1/2021        30355285
# YouTube      3/1/2021        30306486
# SoundCloud   3/1/2021        28313445
# Pandora      2/1/2021        23767711
# Tidal        2/1/2021        22281922
#              4/1/2021        11456780
# Amazon       5/1/2021        11354207
#              1/1/2021         8216840
# Tidal        1/1/2021         7413934
# Melodyv      4/1/2021         2936182
# iHeart Radio 2/1/2021         1951719
# Melodyv      5/1/2021         1250245
#              1/1/2021         1198230
# AudioMack    2/1/2021         1031131
# SoundCloud   1/1/2021          683772
# GTL          1/1/2021          469785
#              2/1/2021          344410
#              4/1/2021          297426
#              5/1/2021          168258
# NugsNet      2/1/2021          110709
# LiveXLive    2/1/2021           95126
# Deezer       1/1/2021           82163
# Trebel       2/1/2021           81756
# Midwest Tape 2/1/2021           65052
# Anghami      2/1/2021           34682
# Trebel       3/1/2021           28179
#              4/1/2021           23918
#              5/1/2021           15494
# Sonos        3/1/2021           11836
#              2/1/2021           10076

# %%
spotify_df = mlc["dsp"].isin(['Spotify'])
spotify_df = mlc[spotify_df]
spotify_df.head()
# Out:
#             isrc country_code registrant_code  year usage_period      dsp  \
# 5   QZJ842000983           QZ             J84    20     3/1/2021  Spotify
# 8   USRC12100543           US             RC1    21     3/1/2021  Spotify
# 9   USAT22007048           US             AT2    20     3/1/2021  Spotify
# 11  QMCE32100237           QM             CE3    21     1/1/2021  Spotify
# 12  USAT22100145           US             AT2    21     5/1/2021  Spotify
#
#     streams recording_artist recording_label      recording_title  \
# 5      8133           x0o0x_          x0o0x_               ______
# 8     28419           2worth    die happy <3  ¡!gu4na:D////:>_<^^
# 9     28419           2worth    die happy <3  ¡!gu4na:D////:>_<^^
# 11    14118  Alaina Castillo   Chosen People             ¡párate!
# 12   107079            dodie     doddleoddle                    ?
#
#           release_title  duration  songwriters_listed
# 5                ______       142                   0
# 8   ¡!gu4na:D////:>_<^^       126                   1
# 9   ¡!gu4na:D////:>_<^^       126                   1
# 11             ¡párate!       154                   1
# 12      Build A Problem        73                   1

# %%
apple_df = mlc["dsp"].isin(["Apple"])
apple_df = mlc[apple_df]
apple_df.head()
# Out:
#             isrc country_code registrant_code  year usage_period    dsp  \
# 6   USUG12100126           US             UG1    21     3/1/2021  Apple
# 10  USLD91730830           US             LD9    17     3/1/2021  Apple
# 16  USUM72100564           US             UM7    21     3/1/2021  Apple
# 18  USUG12100638           US             UG1    21     3/1/2021  Apple
# 22  USUM72024670           US             UM7    20     3/1/2021  Apple
#
#     streams              recording_artist          recording_label  \
# 6      5839                Quentin Miller          1317 Recordings
# 10    44239         Banda Los Sebastianes   Universal Music Mexico
# 16    19336  Banda MS de Sergio Lizárraga              Lizos Music
# 18    18709                    Los Parras             La R Records
# 22    91394              Omy de Oro, Mora  Rimas Entertainment LLC
#
#          recording_title                  release_title  duration  \
# 6       _A_ (feat. Pe$o)                           Q.M.       199
# 10            ¡Ay Dolor!                     ¡Ay Dolor!       227
# 16       ¿Dónde Están?        El Trabajo Es la Suerte       168
# 18  ¿Lloro? O ¿No Lloro?  ¿Lloro? O ¿No Lloro? - Single       180
# 22        ¿Qué Tú Dices?           Primer Día de Clases       223
#
#     songwriters_listed
# 6                    1
# 10                   1
# 16                   1
# 18                   1
# 22                   1

# %%
pandora_df = mlc['dsp'].isin(['Pandora'])
pandora_df = mlc[pandora_df]
pandora_df.head()
# Out:
#             isrc country_code registrant_code  year usage_period      dsp  \
# 21  USUG12100638           US             UG1    21     1/1/2021  Pandora
# 25  USUG12004195           US             UG1    20     2/1/2021  Pandora
# 33  USAT22007048           US             AT2    20     1/1/2021  Pandora
# 34  USUM72023842           US             UM7    20     1/1/2021  Pandora
# 35  USSM12005346           US             SM1    20     1/1/2021  Pandora
#
#     streams              recording_artist    recording_label  \
# 21    16935             Cultura Profética  Cultura Profética
# 25     9717  Banda MS de Sergio Lizárraga        Lizos Music
# 33    11895                 Angel Vivaldi               none
# 34    44577                 Angel Vivaldi               none
# 35    15500                 Angel Vivaldi               none
#
#                                       recording_title  \
# 21  ¿Qué Será? / Ritmo Que Pesa / Suelta los Amarr...
# 25                               ¿Quién Pierde Más?
# 33                                          . _ _ _ _
# 34                                          . _ _ _ _
# 35                                          . . _ _ _
#
#                                         release_title  duration  \
# 21  Single::¿Qué Será? / Ritmo Que Pesa / Suelta l...       834
# 25                            El Trabajo Es la Suerte       199
# 33                                  Single::. _ _ _ _       312
# 34                                  Single::. _ _ _ _       312
# 35                                  Single::. . _ _ _       276
#
#     songwriters_listed
# 21                   0
# 25                   1
# 33                   0
# 34                   0
# 35                   0

# %%
soundcloud_df = mlc['dsp'].isin(['SoundCloud'])
soundcloud_df = mlc[soundcloud_df]
soundcloud_df.head()
# Out:
#              isrc country_code registrant_code  year usage_period         dsp  \
# 1    USRC12100543           US             RC1    21          NaN  SoundCloud
# 2    USSM12102263           US             SM1    21          NaN  SoundCloud
# 68   USUG12100631           US             UG1    21     4/1/2021  SoundCloud
# 136  QMRSZ2100337           QM             RSZ    21     4/1/2021  SoundCloud
# 137  USQX92005133           US             QX9    20     3/1/2021  SoundCloud
#
#      streams  recording_artist   recording_label  \
# 1       8597          LUCKY3RD          LUCKY3RD
# 2     261280          LUCKY3RD          LUCKY3RD
# 68     13996        La La Mofk        La La Mofk
# 136     2127  spiritual moment  Spiritual Moment
# 137     2127  spiritual moment  Spiritual Moment
#
#                                        recording_title  \
# 1                               Keep It Cool  LUCKY3RD
# 2                               Life Goes On  LUCKY3RD
# 68                                     “Hard As Meefk”
# 136  [Try Listening for 3 Minutes] FALL ASLEEP FAST...
# 137  [Try Listening for 3 Minutes] FALL ASLEEP FAST...
#
#                                          release_title  duration  \
# 1                               Keep It Cool  LUCKY3RD       133
# 2                               Life Goes On  LUCKY3RD       171
# 68                                     “Hard As Meefk”        54
# 136  [Try Listening for 3 Minutes] FALL ASLEEP FAST...      3818
# 137  [Try Listening for 3 Minutes] FALL ASLEEP FAST...      3818
#
#      songwriters_listed
# 1                     0
# 2                     0
# 68                    0
# 136                   0
# 137                   0

# %%
youtube_df = mlc['dsp'].isin(['YouTube'])
youtube_df = mlc[youtube_df]
youtube_df.head()
# Out:
#              isrc country_code registrant_code  year usage_period      dsp  \
# 26   GBAHS2100229           GB             AHS    21          NaN  YouTube
# 83   USLD91731547           US             LD9    17     3/1/2021  YouTube
# 98   USUG12100126           US             UG1    21     3/1/2021  YouTube
# 99   USAT22006621           US             AT2    20     4/1/2021  YouTube
# 171  USAT22007702           US             AT2    20     4/1/2021  YouTube
#
#      streams                   recording_artist  \
# 26     12560  Bad Bunny|Benito Antonio Martinez
# 83     21917                             L.T.D.
# 98    186279                 The Rolling Stones
# 99    186279                 The Rolling Stones
# 171   120497                       Babyface Ray
#
#                    recording_label  \
# 26         Rimas Entertainment LLC
# 83                     Budget (AM)
# 98   ABKCO Music and Records, Inc.
# 99   ABKCO Music and Records, Inc.
# 171                      Wavy Gang
#
#                                    recording_title      release_title  \
# 26                                 ¿Quien Tu Eres?           X 100PRE
# 83   (Every Time I Turn Around) Back In Love Again  Something to Love
# 98                   (I Can't Get No) Satisfaction   Out Of Our Heads
# 99                   (I Can't Get No) Satisfaction   Out Of Our Heads
# 171                                         #1 Fan       For You - EP
#
#      duration  songwriters_listed
# 26        160                   0
# 83        281                   0
# 98        223                   0
# 99        223                   0
# 171       195                   0

# %%
spotify_usage_stream = spotify_df.groupby(['usage_period'])['streams'].sum()
spotify_usage_stream.head()
# Out:
# usage_period
# 1/1/2021     497157870
# 2/1/2021     194262015
# 3/1/2021    1070556892
# 4/1/2021     233054084
# 5/1/2021     557532861
# Name: streams, dtype: int32

# %%
apple_usage_stream = apple_df.groupby(['usage_period'])['streams'].sum()
apple_usage_stream.head()
# Out:
# usage_period
# 1/1/2021    386489626
# 2/1/2021    103344401
# 3/1/2021    596790646
# 4/1/2021    191327008
# 5/1/2021    152393670
# Name: streams, dtype: int32

# %%
pandora_usage_stream = pandora_df.groupby(['usage_period'])['streams'].sum()
pandora_usage_stream.head()
# Out:
# usage_period
# 1/1/2021    640744206
# 2/1/2021     23767711
# 3/1/2021    117910699
# 4/1/2021     61458665
# 5/1/2021     30355285
# Name: streams, dtype: int32

# %%
soundcloud_usage_stream = soundcloud_df.groupby(['usage_period'])['streams'].sum()
soundcloud_usage_stream.head()
# Out:
# usage_period
# 1/1/2021      683772
# 2/1/2021    41528178
# 3/1/2021    28313445
# 4/1/2021    68215817
# Name: streams, dtype: int32

# %%
youtube_usage_stream = youtube_df.groupby(['usage_period'])['streams'].sum()
youtube_usage_stream.head()
#plt.plot(youtube_usage_stream)
# Out:
# usage_period
# 2/1/2021    43092176
# 3/1/2021    30306486
# 4/1/2021    39801971
# Name: streams, dtype: int32

# %% [markdown]
# # Spotify usage plot

# %%
plt.plot(spotify_usage_stream)

# %% [markdown]
# # Apple usage plot

# %%
plt.plot(apple_usage_stream)

# %% [markdown]
# # Pandora usage plot

# %%
plt.plot(pandora_usage_stream)

# %% [markdown]
# # SounCloud usage plot

# %%
plt.plot(soundcloud_usage_stream)

# %% [markdown]
# # YouTube usage plot

# %%
plt.plot(youtube_usage_stream)

# %%
pop_yr_spot = spotify_df.groupby(['dsp', 'year']).agg({'streams': ['sum']})
pop_yr_spot.columns = ['streams']
pop_yr_spot.head().sort_values(by='streams', ascending=False)
# Out:
#                streams
# dsp     year
# Spotify 4     18608832
#         1      8819809
#         2      8235148
#         3      6042872
#         0      3898657

# %%
pop_yr_apple = apple_df.groupby(['dsp', 'year']).agg({'streams': ['sum']})
pop_yr_apple.columns = ['streams']
pop_yr_apple.head().sort_values(by='streams', ascending=False)
# Out:
#             streams
# dsp   year
# Apple 4     6894785
#       0     6153111
#       3     5427324
#       2     3757843
#       1     3311732

# %%
pop_yr_soundcloud = soundcloud_df.groupby(['dsp', 'year']).agg({'streams': ['sum']})
pop_yr_soundcloud.columns = ['streams']
pop_yr_soundcloud.head().sort_values(by='streams', ascending=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 57 entries, ('SoundCloud', 0) to ('SoundCloud', 99)
# Data columns (total 1 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   streams  57 non-null     int32
# dtypes: int32(1)
# memory usage: 911.0+ bytes

# %%
pop_yr_pandora = pandora_df.groupby(['dsp', 'year']).agg({'streams': ['sum']})
pop_yr_pandora.columns = ['streams']
pop_yr_pandora.head().sort_values(by='streams', ascending=False)
# Out:
#               streams
# dsp     year
# Pandora 4     9013623
#         1     4738180
#         0     2402284
#         2     1919479
#         3     1912877

# %%
pop_yr_youtube = youtube_df.groupby(['dsp', 'year']).agg({'streams': ['sum']})
pop_yr_youtube.columns = ['streams']
pop_yr_youtube.head().sort_values(by='streams', ascending=False)
# Out:
#               streams
# dsp     year
# YouTube 4     1132576
#         3     1061897
#         0      337093
#         1      253236
#         2      233270

# %%
mlc_yr = mlc.groupby(['year']).agg({'streams': ['sum']})
mlc_yr.columns = ['streams']
mlc_yr.head().sort_values(by='streams', ascending=False)
# Out:
#        streams
# year
# 4     38021414
# 1     17840031
# 2     15594435
# 3     15423605
# 0     13666895

# %%
mlc['year'].value_counts().head(100)
# Out:
# 20    31143
# 21    13510
# 19    11577
# 18     8556
# 17     6025
#       ...
# 44        2
# 50        1
# 48        1
# 49        1
# 40        1
# Name: year, Length: 95, dtype: Int64

# %%
no_writer = mlc[mlc.songwriters_listed == 0]

# %%
III_no_writer = mlc['recording_label'].isin(['300 Entertainment'])

# %%
no_writer[III_no_writer].groupby(['dsp'])['streams'].sum().sort_values(ascending=False)
# Out:
# C:\Users\robsc\AppData\Local\Temp/ipykernel_8204/463183033.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   no_writer[III_no_writer].groupby(['dsp'])['streams'].sum().sort_values(ascending=False)
# dsp
# Apple           38342719
# Spotify         28933479
# Pandora          8453107
# Amazon            748441
# YouTube           519605
# SoundCloud         27421
# Melodyv            26679
# iHeart Radio       16482
# GTL                 3961
# LiveXLive             50
# Name: streams, dtype: int32

# %%
pandora_no_writer = no_writer['dsp'].isin(['Pandora'])

# %%
pandora_no_writer = no_writer[pandora_no_writer]

# %%
pandora_no_writer.groupby(['recording_label'])['streams'].sum().sort_values(ascending=False)
# Out:
# recording_label
# eOne Music                23336260
# Atlantic Records          19750207
# Never Broke Again, LLC    12989423
# Big Boy Records           11419705
# Death Row Records         10351530
#                             ...
# Lyric House LLC                152
# flipturn                       148
# Prospect Park                   68
# Haley Smalls                    51
# Gabi DeMartino                  17
# Name: streams, Length: 2173, dtype: int32
