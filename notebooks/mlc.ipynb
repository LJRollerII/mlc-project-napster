# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
mlc = pd.read_csv('C:/NSS/Projects/mlc-project-napster/data/Matching Sample for NSS (100k Lines).xlsx - MLC Data Sample.csv')

# %%
print(mlc.head(100))
# Out:
#              If  Country Code Registrant Code  Year of Reference Usage Period  \
# 0   USUG12101043           US             UG1               21.0          NaN
# 1   USRC12100543           US             RC1               21.0          NaN
# 2   USSM12102263           US             SM1               21.0          NaN
# 3   USLD91731547           US             LD9               17.0     2/1/2021
# 4   USAT22007048           US             AT2               20.0          NaN
# ..           ...          ...             ...                ...          ...
# 95  USUG12100126           US             UG1               21.0     1/1/2021
# 96  USAT22005550           US             AT2               20.0     1/1/2021
# 97  USUM72105621           US             UM7               21.0     1/1/2021
# 98  USUG12100126           US             UG1               21.0     3/1/2021
# 99  USAT22006621           US             AT2               20.0     4/1/2021
#
# ...

# %%
mlc.columns = ['ISRC', 'Country_Code', 'Registrant_Code', 'Year_of_Reference', 'Usage_Period', 'Streaming_Platform_(DSP)', 'Streams', 'Recording_Artist', 'Recording_Label', 'Recording_Title', 'Release_Title', 'Recording_Duration_(Seconds)', 'Songwriters_Listed']
mlc.head()
# Out:
#            ISRC Country_Code Registrant_Code  Year_of_Reference Usage_Period  \
# 0  USUG12101043           US             UG1               21.0          NaN
# 1  USRC12100543           US             RC1               21.0          NaN
# 2  USSM12102263           US             SM1               21.0          NaN
# 3  USLD91731547           US             LD9               17.0     2/1/2021
# 4  USAT22007048           US             AT2               20.0          NaN
#
#   Streaming_Platform_(DSP)     Streams        Recording_Artist  \
# 0                AudioMack     10,175                   Future
# 1               SoundCloud      8,597                 LUCKY3RD
# 2               SoundCloud    261,280                 LUCKY3RD
# 3                   Trebel          5   Bachata & Merengue Mix
# 4                AudioMack     62,105                   Foolio
#
#   Recording_Label                            Recording_Title  \
# ...

# %%
mlc.head()
# Out:
#            ISRC Country_Code Registrant_Code  Year_of_Reference Usage_Period  \
# 0  USUG12101043           US             UG1               21.0          NaN
# 1  USRC12100543           US             RC1               21.0          NaN
# 2  USSM12102263           US             SM1               21.0          NaN
# 3  USLD91731547           US             LD9               17.0     2/1/2021
# 4  USAT22007048           US             AT2               20.0          NaN
#
#   Streaming_Platform_(DSP)     Streams        Recording_Artist  \
# 0                AudioMack     10,175                   Future
# 1               SoundCloud      8,597                 LUCKY3RD
# 2               SoundCloud    261,280                 LUCKY3RD
# 3                   Trebel          5   Bachata & Merengue Mix
# 4                AudioMack     62,105                   Foolio
#
#   Recording_Label                            Recording_Title  \
# ...

# %%
no_writer = mlc[mlc.Songwriters_Listed == 0]

# %%
no_writer['Year_of_Reference'] = no_writer['Year_of_Reference'].astype('Int64')
# Out:
# C:\Users\robsc\AppData\Local\Temp/ipykernel_3812/249889259.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   no_writer['Year_of_Reference'] = no_writer['Year_of_Reference'].astype('Int64')

# %%
print(no_writer.shape)
# Out:
# (45839, 13)

# %%
no_writer['Year_of_Reference']=no_writer['Year_of_Reference'].fillna(0)
# Out:
# C:\Users\robsc\AppData\Local\Temp/ipykernel_3812/3748079105.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   no_writer['Year_of_Reference']=no_writer['Year_of_Reference'].fillna(0)

# %%
no_writer['Streams']=no_writer['Streams'].str.replace(',','')
# Out:
# C:\Users\robsc\AppData\Local\Temp/ipykernel_3812/1501110699.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   no_writer['Streams']=no_writer['Streams'].str.replace(',','')

# %%
no_writer['Streams']=no_writer['Streams'].astype(int)
# Out:
# C:\Users\robsc\AppData\Local\Temp/ipykernel_3812/850714712.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   no_writer['Streams']=no_writer['Streams'].astype(int)

# %%
max_streams = no_writer.sort_values(
     by="Streams",
     ascending=False,
    )

# %%
max_streams.head(20)
# Out:
#                ISRC Country_Code Registrant_Code  Year_of_Reference  \
# 65920  QZHN82036983           QZ             HN8                 20
# 66711  USKBB2100008           US             KBB                 21
# 78396  USUYG1132974           US             UYG                 11
# 35910  USZHR1500004           US             ZHR                 15
# 78751  INS171701687           IN             S17                 17
# 447    USUM72102632           US             UM7                 21
# 69629           NaN          NaN             NaN               -999
# 33526  USWD11366376           US             WD1                 13
# 19930  QM3E22014063           QM             3E2                 20
# 98559  GBLV62040593           GB             LV6                 20
# 96     USAT22005550           US             AT2                 20
# 8228   USLD91722171           US             LD9                 17
# 4780   USUM72022978           US             UM7                 20
# ...

# %%
no_writer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 45839 entries, 0 to 99983
# Data columns (total 13 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   ISRC                          45015 non-null  object
#  1   Country_Code                  45041 non-null  object
#  2   Registrant_Code               45041 non-null  object
#  3   Year_of_Reference             45839 non-null  Int64
#  4   Usage_Period                  40016 non-null  object
#  5   Streaming_Platform_(DSP)      43026 non-null  object
#  6   Streams                       45839 non-null  int32
#  7   Recording_Artist              45839 non-null  object
#  8   Recording_Label               44897 non-null  object
#  9   Recording_Title               45839 non-null  object
#  10  Release_Title                 45798 non-null  object
#  11  Recording_Duration_(Seconds)  45839 non-null  int64
# ...

# %%
no_writer.tail()
# Out:
#                ISRC Country_Code Registrant_Code  Year_of_Reference  \
# 99968  QZHN72010372           QZ             HN7                 20
# 99970  SEBGA1902966           SE             BGA                 19
# 99972  QZFYW2165515           QZ             FYW                 21
# 99980  QZHN62064279           QZ             HN6                 20
# 99983  QZNWU2090125           QZ             NWU                 20
#
#       Usage_Period Streaming_Platform_(DSP)  Streams  Recording_Artist  \
# 99968     3/1/2021                  YouTube    16621        ChiliChill
# 99970     3/1/2021                  Spotify     9343  Yoshihisa Hirano
# 99972     3/1/2021                  Spotify    14428  Yoshihisa Hirano
# 99980     3/1/2021                  Spotify    25708            JJ Lin
# 99983     3/1/2021                  Spotify    14477                李志
#
#          Recording_Label           Recording_Title  \
# 99968     StreetVoice 街聲  让风告诉你 (游戏《原神》2021拜年纪同人曲)
# ...

# %%
no_writer.isnull().sum()
# Out:
# ISRC                             824
# Country_Code                     798
# Registrant_Code                  798
# Year_of_Reference                  0
# Usage_Period                    5823
# Streaming_Platform_(DSP)        2813
# Streams                            0
# Recording_Artist                   0
# Recording_Label                  942
# Recording_Title                    0
# Release_Title                     41
# Recording_Duration_(Seconds)       0
# Songwriters_Listed                 0
# dtype: int64

# %%
no2 = no_writer.groupby(['Recording_Artist'])['Recording_Title'].count()

# %%
no2_sort = no2.sort_values(byascending=False)

# %%
no2_sort.head(25)
# Out:
# Recording_Artist
# Various artists               710
# Youngboy Never Broke Again    295
# Nipsey Hussle                 252
# Lil Durk                      248
# Upchurch                      210
# Pinkfong                      210
# Taylor Swift                  206
# Larry June                    192
# DaBaby                        188
# Jelly Roll                    178
# Young Dolph                   176
# Moneybagg Yo                  175
# Billy Strings                 174
# Lemon Demon                   155
# Sleepy Hallow                 152
# Key Glock                     148
# Rod Wave                      145
# Dean Evenson                  144
# Eminem                        143
# Ghostemane                    140
# Gucci Mane                    137
# Moosaa Richardson             137
# 42 DUGG                       135
# Kodak Black                   124
# Tom MacDonald                 122
# Name: Recording_Title, dtype: int64

# %%
no2_sum_streams = no_writer.groupby(['Recording_Artist'])['Streams'].sum()

# %%
no2_sum_streams = no2_sum_streams.sort_values(ascending=False)

# %%
no2_sum_streams.head(40)
# Out:
# Recording_Artist
# Youngboy Never Broke Again                  19178281
# Israel Kamakawiwo'ole                       16576598
# Young Thug, Young Stoner Life, Gunna        14885508
# Polo G                                      13889461
# Rod Wave                                    12485805
# 2Pac|The Outlawz                            12418408
# Snoop Dogg                                  10293343
# Olivia Rodrigo                              10261424
# Pooh Shiesty                                 9383633
# Tee Grizzley                                 9149085
# Lil Durk, King Von, Booka600                 9056015
# Young Dolph                                  9035659
# Various artists                              9017733
# Kevin Gates                                  8810681
# Nipsey Hussle                                8438288
# Young Stoner Life,Young Thug,Gunna,Drake     8420184
# Key Glock                                    8284326
# ...

# %%
no2_sum_streams_RL = no_writer.groupby(['Recording_Label'])['Streams'].sum()      
no2_sum_streams_RL = no2_sum_streams_RL.sort_values(ascending=False)

# %%
no2_sum_streams_RL.head(40)
# Out:
# Recording_Label
# 300 Entertainment                            77185742
# Atlantic Records                             41818113
# Only The Family / EMPIRE                     27834316
# eOne Music                                   23985067
# Paper Route EMPIRE                           22656910
# Columbia                                     20031438
# Big Boy Records                              15953550
# Universal                                    15891329
# Never Broke Again, LLC                       15070025
# Warner Records                               14220805
# H$M Music / EMPIRE                           13402966
# Winners Circle Entertainment Inc / EMPIRE    11839742
# WMG                                          11710464
# Walt Disney Records                          10736691
# Death Row Records                            10653214
# Sony Music                                   10507443
# Vandross Music Group, Inc. / EMPIRE           9836673
# ...

# %%
no2_sum_streams_RD = no_writer.groupby(['Recording_Duration_(Seconds)'])['Recording_Artist'].nunique()      
no2_sum_streams_RD = no2_sum_streams_RD.sort_values(ascending=False)

# %%
no2_sum_streams_RD.head(40)
# Out:
# Recording_Duration_(Seconds)
# 192    250
# 193    226
# 182    216
# 201    209
# 199    208
# 195    202
# 188    202
# 185    200
# 189    196
# 202    195
# 181    193
# 190    192
# 200    192
# 203    187
# 210    185
# 197    185
# 186    185
# 177    185
# 191    183
# 198    183
# 211    180
# 170    180
# 206    179
# 184    177
# 194    173
# 169    172
# 178    171
# 212    171
# 180    170
# 214    168
# 196    168
# 220    168
# 219    167
# 179    167
# 172    167
# 165    166
# 213    166
# 183    166
# 205    165
# 204    165
# Name: Recording_Artist, dtype: int64

# %%
III_ent_artists  = no_writer.Recording_Label.isin(["300 Entertainment"])
no_writer[III_ent_artists].sort_values(by="Streams",ascending=False).head(35)
# Out:
#                ISRC Country_Code Registrant_Code  Year_of_Reference  \
# 78396  USUYG1132974           US             UYG                 11
# 19930  QM3E22014063           QM             3E2                 20
# 78398  USNLR1900424           US             NLR                 19
# 78397  US3U80502481           US             3U8                  5
# 76913  USCGJ0503418           US             CGJ                  5
# 95696  USQNL1100007           US             QNL                 11
# 35507  QMCE32100294           QM             CE3                 21
# 64290  USASN1400149           US             ASN                 14
# 76914  GBWUL1822597           GB             WUL                 18
# 96909  BRITK1802973           BR             ITK                 18
# 69783  QZKWA2023704           QZ             KWA                 20
# 69784  USQY51733888           US             QY5                 17
# 61679  TCAFK2177573           TC             AFK                 21
# ...

# %%
no_writer['Recording_Artist'][III_ent_artists].nunique()
# Out:
# 81

# %%
rl_ra_count = no_writer.groupby(['Recording_Label'])['Recording_Artist'].nunique()
rl_ra_count.sort_values(ascending=False).head(10)
# Out:
# Recording_Label
# Universal              415
# WMG                    262
# Sony Music             201
# EMPIRE Distribution    144
# Atlantic Records       139
# Orchard                138
# Distro Kid             128
# Default                111
# TuneCore                93
# Routenote               93
# Name: Recording_Artist, dtype: int64

# %%
spdsp_streams_sum = no_writer.groupby(['Streaming_Platform_(DSP)'])['Streams'].sum()
spdsp_streams_sum.sort_values(ascending=False).head()
# Out:
# Streaming_Platform_(DSP)
# Pandora       665457918
# Spotify       280344577
# Apple         238835322
# SoundCloud    166813813
# YouTube       158031119
# Name: Streams, dtype: int32
